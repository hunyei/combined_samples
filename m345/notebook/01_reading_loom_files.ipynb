# %%
import anndata

# %%
m5_adata_copy = anndata.read_loom("/blue/square.t/peter.huynh/jupyter/combined_samples_scvelo/m345/data/raw/ms345_unf_possorted_genome_bam_UENJ0.loom")
# Out:
# /blue/square.t/miniconda3/envs/scvelo_033_scrublet/lib/python3.10/site-packages/anndata/_core/anndata.py:1899: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
#safe checkpoint
m5_adata=m5_adata_copy.copy()
# Out:
# /blue/square.t/miniconda3/envs/scvelo_033_scrublet/lib/python3.10/site-packages/anndata/_core/anndata.py:1899: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
m5_adata.var_names_make_unique()

# %%
#save this to raw
m5_adata.write("/blue/square.t/peter.huynh/jupyter/combined_samples_scvelo/m345/data/raw/m5_adata.h5ad")
